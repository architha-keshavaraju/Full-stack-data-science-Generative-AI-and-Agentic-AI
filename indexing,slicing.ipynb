# %%
str = 'hello'
str
# Out:
# 'hello'

# %%
str[0]
# Out:
# 'h'

# %%
print(str[0])
print(str[1])
print(str[2])
print(str[3])
print(str[4])
# Out:
# h
# e
# l
# l
# o

# %%
print(str[-1])
print(str[-2])
print(str[-3])
print(str[-4])
print(str[-5])
# Out:
# o
# l
# l
# e
# h

# %%
len(str)
# Out:
# 5

# %%
str[1:3]
# Out:
# 'el'

# %%
str[0:4]
# Out:
# 'hell'

# %%
s = 'hellopython'
s
# Out:
# 'hellopython'

# %%
s[0:6]
# Out:
# 'hellop'

# %%
s[0:10:3]
# Out:
# 'hlyo'

# %%
s[2:10:2]
# Out:
# 'loyh'

# %%
s[1:8:2]
# Out:
# 'elpt'

# %%
s[::1]
# Out:
# 'hellopython'

# %%
s[::2]
# Out:
# 'hloyhn'

# %%
s[::3]
# Out:
# 'hlyo'

# %%
s3 ='hello'
s4 ='hi'
print(s3 + s4)
# Out:
# hellohi
