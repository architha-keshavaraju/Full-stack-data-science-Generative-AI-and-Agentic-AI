# %% [markdown]
# # Operators

# %% [markdown]
# # Arithmetic operators

# %%
x1 = 10
y1 = 5

# %%
x1,y1 = 10,5 #no. of var = no. of values

# %%
a,b = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 a,b = 6
#
# TypeError: cannot unpack non-iterable int object

# %%
x1+y1
# Out:
# 15

# %%
x1-y1
# Out:
# 5

# %%
x1*y1
# Out:
# 50

# %%
x1/y1
# Out:
# 2.0

# %%
x1//y1
# Out:
# 2

# %%
x1%y1
# Out:
# 0

# %%
x1**y1
# Out:
# 100000

# %%
3 ** 2
# Out:
# 9

# %% [markdown]
# # Assignment operators

# %%
x = 2

# %%
x = x+2
x
# Out:
# 4

# %%
x += 2
x
# Out:
# 6

# %%
x += 2
x
# Out:
# 8

# %%
x *= 2
x
# Out:
# 16

# %%
x -= 2
x
# Out:
# 14

# %%
x /= 2
x
# Out:
# 7.0

# %%
x //= 2
x
# Out:
# 3.0

# %%
x = 14 
x //= 2
x
# Out:
# 7

# %% [markdown]
# # Unary operators

# %%
n = 7

# %%
n = -(n)
n
# Out:
# -7

# %% [markdown]
# # Relational operators

# %%
a = 5
b = 6

# %%
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
b = 5 #changing to 5

# %%
a == b
# Out:
# True

# %%
a
# Out:
# 5

# %%
b
# Out:
# 5

# %%
a>b
# Out:
# False

# %%
a>=b
# Out:
# True

# %%
a<=b
# Out:
# True

# %%
b=7

# %%
a<b
# Out:
# True

# %% [markdown]
# # Logical operators

# %%
a = 5
b = 4

# %%
a < 8 and b < 5
# Out:
# True

# %%
a < 8 and b < 2
# Out:
# False

# %%
a < 8 or b < 2
# Out:
# True

# %%
a > 8 or b < 2
# Out:
# False

# %%
x = False
x
# Out:
# False

# %%
not x
# Out:
# True

# %%
not (not x)
# Out:
# False

# %% [markdown]
# # Python Bitwise Operators

# %% [markdown]
# # Complement

# %%
~12
# Out:
# -13

# %%
~46
# Out:
# -47

# %%
~54
# Out:
# -55

# %%
~10
# Out:
# -11

# %% [markdown]
# # -Number system-

# %%
25
# Out:
# 25

# %%
bin(25)
# Out:
# '0b11001'

# %%
0b11001
# Out:
# 25

# %%
bin(30)
# Out:
# '0b11110'

# %%
oct(25)
# Out:
# '0o31'

# %%
0o31
# Out:
# 25

# %%
int(0o31)
# Out:
# 25

# %%
int(0b11110)
# Out:
# 30

# %%
hex(25)
# Out:
# '0x19'

# %%
hex(16)
# Out:
# '0x10'

# %%
0xa
# Out:
# 10

# %% [markdown]
# # '&' and '|' operators

# %%
12 & 13
# Out:
# 12

# %%
12 | 13
# Out:
# 13

# %%
1 & 0
# Out:
# 0

# %%
1 | 0
# Out:
# 1

# %%
print(bin(35))
print(bin(40))
# Out:
# 0b100011
# 0b101000

# %%
35 & 40
# Out:
# 32

# %%
print(bin(32))
# Out:
# 0b100000

# %%
35 | 40
# Out:
# 43

# %% [markdown]
# # XOR operator

# %%
12 ^ 13
# Out:
# 1

# %%
25 ^ 30
# Out:
# 7

# %% [markdown]
# # Left shift and Right shift

# %%
bin(10)
# Out:
# '0b1010'

# %%
10<<1
# Out:
# 20

# %%
10<<2
# Out:
# 40

# %%
10 >> 1
# Out:
# 5

# %%
10 >> 2
# Out:
# 2

# %%
10 >> 3
# Out:
# 1

# %%
bin(20)
# Out:
# '0b10100'

# %%
20 >> 4
# Out:
# 1
